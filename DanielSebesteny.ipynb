# %%
# Task 1.

number = '1s2'
task1_list = [123, 'abc15', True, [4, 9, 12, 'a'], {1: 'Egy', 2: 'ketto', 3: 'harom', 4: 'ot'}]

# %%
# Task 2.

num = list(number)
num.remove('s')
number = ''
for elem in num:
    number += elem
number = int(number)

# %%
# Task 3.

task1_list.append(number)

# %%
# Task 4.

print(task1_list[0]*10, task1_list[0]**2)
# Out:
# 1230 15129

# %%
# Task 5.

task5_list = task1_list.copy()
newelem = task5_list[1]
task5_list.insert(0, newelem[:3])
task5_list.insert(1, newelem[3:])
print(task5_list)
# Out:
# ['abc', '15', 123, 'abc15', True, [4, 9, 12, 'a'], {1: 'Egy', 2: 'ketto', 3: 'harom', 4: 'ot'}, 12]

# %%
# Task 6.

if len(task1_list[3])>5:
    print('Igaz.')
else:
    print('Hamis.')
# Out:
# Hamis.

# %%
# Task 7.

task1_list[3].pop()
task1_list[3].append(sum(task1_list[3]))
print(task1_list)
# Out:
# [123, 'abc15', True, [4, 9, 12, 25], {1: 'Egy', 2: 'ketto', 3: 'harom', 4: 'ot'}, 12]

# %%
# Task 8.

for key, value in task1_list[4].items():
    task1_list[4][key] = task1_list[4][key].capitalize()
task1_list[4][4] = 'Negy'
print(task1_list)
# Out:
# [123, 'abc15', True, [4, 9, 12, 25], {1: 'Egy', 2: 'Ketto', 3: 'Harom', 4: 'Negy'}, 12]

# %%
# Task 9.

task1_list[4][5] = 'ÖT'
print(task1_list)
# Out:
# [123, 'abc15', True, [4, 9, 12, 25], {1: 'Egy', 2: 'Ketto', 3: 'Harom', 4: 'Negy', 5: 'ÖT'}, 12]
